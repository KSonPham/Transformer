# %%
import torch
import torch.nn as nn
from torch import Tensor

from torch.nn.functional import log_softmax
from torchtext.datasets import Multi30k
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator, Vocab
from torch.utils.data import DataLoader,IterableDataset,Dataset
from torch.optim.lr_scheduler import LambdaLR
import math as m
import pandas as pd
import spacy
from spacy.symbols import ORTH
import os
import warnings
warnings.filterwarnings('ignore')
torch.manual_seed(0)

# %%
# class CustomDataset(Dataset):
#     def __init__(self,txts_file,labels_file):
#         self.texts = pd.read_csv("Data/"+txts_file,delimiter="\n", header= None)
#         self.label = pd.read_csv("Data/"+labels_file,delimiter="\n", header= None)

#     def __len__(self):
#         return len(self.labels)

#     def __getitem__(self,idx):
#         label = self.labels[idx]
#         text = self.text[idx]
#         sample = {"Text": text, "Class": label}
#         return sample

# class CustomDataset(IterableDataset):
#     def __init__(self,filename_en,filename_gm):
#         self.filename_en = "Data/"+filename_en
#         self.filename_gm = "Data/"+filename_gm

#     def preprocess(self, text):

#         ### Do something with text here
#         trimmed_text = ''.join([x for x in text if x in string.ascii_letters + '\'- '])
#         trimmed_text = trimmed_text.replace("AT-AT"," ")
#         text_pp = trimmed_text.split()
#         ###

#         return text_pp

#     def line_mapper(self, line):
        
#         #We only have the text in the file for this case
#         text = line
#         text = self.preprocess(text)
#         return text


#     def __iter__(self):

#         #Create an iterator
#         en_itr = open(self.filename_en)
#         gm_itr = open(self.filename_gm)
        
#         #Map each element using the line_mapper
#         mapped_en_itr = map(self.line_mapper, en_itr)
#         mapped_gm_itr = map(self.line_mapper, gm_itr)
        
#         #Zip both iterators
#         zipped_itr = zip(mapped_en_itr, mapped_gm_itr)
        
#         return zipped_itr

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, n_head):
        super().__init__()
        self.Qs = []
        self.Ks = []
        self.Vs = []
        self.d_model = d_model
        self.n_head = n_head
        self.softmax = nn.Softmax(dim=-1)
        
        self.Qs = nn.Linear(d_model,d_model,bias=True)
        self.Ks = nn.Linear(d_model,d_model,bias=True)
        self.Vs = nn.Linear(d_model,d_model,bias=True)
        self.mha = nn.Linear(d_model,d_model)

    def scaled_dot_product_attention(self, Q, K, V, mask):
        scaled_dot = torch.matmul(Q, torch.transpose(K,dim0=-2,dim1=-1))/m.sqrt(self.d_model)
        if mask is not None:
            scaled_dot = scaled_dot.masked_fill(mask == 0, -1e9)
        score = self.softmax(scaled_dot)
        attention = torch.matmul(score,V)
        return attention



    def forward(self, q_in, k_in, v_in, mask):
        Q = self.Qs(q_in)
        K = self.Ks(k_in)
        V = self.Vs(v_in)

        batch_size = q_in.shape[0]
        head_size = int(self.d_model/self.n_head)

        Q = Q.reshape(batch_size, self.n_head, -1, head_size)
        K = K.reshape(batch_size, self.n_head, -1, head_size)
        V = V.reshape(batch_size, self.n_head, -1, head_size)
        scaled_dot = self.scaled_dot_product_attention(Q,K,V,mask)
        scaled_dot = scaled_dot.reshape(batch_size, -1, self.d_model)
        output = self.mha(scaled_dot)
        return output

# %%
class Embeddinglayers(nn.Module):
    def __init__(self, vocab_size, padding_idx, d_model):
        super().__init__()
        self.d_model = d_model
        self.embedding = nn.Embedding(vocab_size, d_model, padding_idx=padding_idx)

    def forward(self, x):
        
        embedding = self.embedding(x)
        return embedding * m.sqrt(self.d_model)

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout, max_len=1000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1)
        div_term = torch.exp(
            torch.arange(0, d_model, 2) * -(m.log(10000.0) / d_model)
        )
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer("pe", pe)

    def forward(self, x):
        x = x + self.pe[:, : x.size(1)].requires_grad_(False)
        return self.dropout(x)

# %%
class Encoder(nn.Module):
    def __init__(self,d_model, n_head, hidden_size, dropout):
        super().__init__()
        self.layer_norm = nn.LayerNorm(d_model)
        self.linear1 = nn.Linear(d_model,hidden_size)
        self.linear2 = nn.Linear(hidden_size, d_model)
        self.mha = MultiHeadAttention(d_model,n_head)
        self.activation = nn.ReLU()
        self.dropout = nn.Dropout(p = dropout)

    def forward(self, x, src_mask = None):
        x = self.layer_norm(x + self.dropout(self.mha(x, x, x, src_mask)))
        x = self.layer_norm(x + self.dropout(self.linear_block(x)))
        return x

    def linear_block(self, x:Tensor) -> Tensor:
        out = self.linear2(self.activation(self.linear1(x)))
        return out

# %%
class Encoder_Block(nn.Module):
    def __init__(self, vocab_size, padding_idx, max_length, n_block = 6, d_model = 512, n_head = 8, hidden_size = 2048, dropout=0.1):
        super().__init__()
        self.embedding = Embeddinglayers(vocab_size, padding_idx,d_model)
        self.positional_embedding = PositionalEncoding(d_model, dropout, max_length)
        self.layers = nn.ModuleList([Encoder(d_model, n_head, hidden_size, dropout) for i in range(n_block)])
    def forward(self, x, src_mask = None):
        
            
        x = self.embedding(x)
        x = self.positional_embedding(x)
        for encode in self.layers:
            x = encode(x, src_mask)
        return x

# %%
class Decoder(nn.Module):
    def __init__(self,d_model, n_head, hidden_size, dropout):
        super().__init__()
        
        self.layer_norm = nn.LayerNorm(d_model)
        self.linear1 = nn.Linear(d_model,hidden_size)
        self.linear2 = nn.Linear(hidden_size, d_model)
        self.mha_1 = MultiHeadAttention(d_model,n_head)
        self.mha_2 = MultiHeadAttention(d_model,n_head)
        self.activation = nn.ReLU()

        self.dropout = nn.Dropout(p = dropout)

    def forward(self,x, encoder_in, src_mask = None, trg_mask = None):
        x = self.layer_norm(x + self.dropout(self.mha_1(x, x, x, trg_mask)))
        x = self.layer_norm(x + self.dropout(self.mha_2(x, encoder_in, encoder_in, src_mask)))
        x = self.layer_norm(x + self.dropout(self.linear_block(x)))
        return x

    def linear_block(self, x:Tensor) -> Tensor:
        out = self.linear2(self.activation(self.linear1(x)))
        return out

# %%
class Decoder_Block(nn.Module):
    def __init__(self, vocab_size, padding_idx, max_length, n_block = 6, d_model = 512, n_head = 8, hidden_size = 2048, dropout=0.1):
        super().__init__()
        self.embedding = Embeddinglayers(vocab_size, padding_idx,d_model)
        self.positional_embedding = PositionalEncoding(d_model, dropout, max_length)
        self.layers = nn.ModuleList([Decoder(d_model,n_head,hidden_size,dropout) for i in range(n_block)])
    def forward(self,x, enconder_in, src_mask = None, trg_mask = None):
        x = self.embedding(x)
        x = self.positional_embedding(x)
        for decode in self.layers:
            x = decode(x, enconder_in, src_mask,trg_mask)
        return x

# %%
class Transformer(nn.Module):
    def __init__(self, src_vocab_size, trg_vocab_size, padding_idx, max_length, device = 'cuda:0', n_block = 6, d_model = 512, n_head = 8, hidden_size = 2048, dropout=0.1):
        super().__init__()
        self.padding_idx = padding_idx
        self.device = device
        self.enc_block = Encoder_Block(src_vocab_size,padding_idx,max_length,n_block,d_model,n_head,hidden_size,dropout)
        self.dec_block = Decoder_Block(trg_vocab_size,padding_idx,max_length,n_block,d_model,n_head,hidden_size,dropout)
        self.proj = nn.Linear(d_model, trg_vocab_size)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)

    def forward(self,src,trg):
        src_mask = self.make_src_mask(src)
        trg_mask = self.make_trg_mask(trg)
        enc_out = self.enc_block(src,src_mask)
        dec_out = self.dec_block(trg,enc_out,src_mask,trg_mask)
        
        out = self.proj(dec_out)
        return out

    def make_src_mask(self, src):
        src_mask = (src != self.padding_idx).unsqueeze(-2)
       
        return src_mask.unsqueeze(1)

    def make_trg_mask(self, trg):
        pad_mask = (trg != self.padding_idx).unsqueeze(-2)
        no_peak_mask = torch.triu(torch.ones((1, trg.shape[1], trg.shape[1])))
        no_peak_mask = no_peak_mask.transpose(dim0=-1, dim1 = -2).type_as(trg.data)

        trg_mask = no_peak_mask & pad_mask
        return trg_mask.unsqueeze(1)

# %%
def tokenize(text, tokenizer):
    return [tok.text for tok in tokenizer.tokenizer(text)]


def yield_tokens(data_iter, tokenizer, index):
    for from_to_tuple in data_iter:
        yield tokenizer(from_to_tuple[index])

def build_vocabulary(spacy_de, spacy_en):
    def tokenize_de(text):
        return tokenize(text, spacy_de)

    def tokenize_en(text):
        return tokenize(text, spacy_en)

    print("Building German Vocabulary ...")
    train, val, test = Multi30k(language_pair=("de", "en"))
    vocab_src = build_vocab_from_iterator(
        yield_tokens(train + val + test, tokenize_de, index=0),
        min_freq=1,
        specials=["<s>", "</s>", "<blank>", "<unk>"],
    )

    print("Building English Vocabulary ...")
    train, val, test = Multi30k(language_pair=("de", "en"))
    vocab_tgt = build_vocab_from_iterator(
        yield_tokens(train + val + test, tokenize_en, index=1),
        min_freq=1,
        specials=["<s>", "</s>", "<blank>", "<unk>"],
    )

    vocab_src.set_default_index(vocab_src["<unk>"])
    vocab_tgt.set_default_index(vocab_tgt["<unk>"])

    return vocab_src, vocab_tgt, [train, val, test]

def load_tokenizers():

    try:
        spacy_de = spacy.load("de_core_news_sm")
    except IOError:
        os.system("python -m spacy download de_core_news_sm")
        spacy_de = spacy.load("de_core_news_sm")

    try:
        spacy_en = spacy.load("en_core_web_sm")
    except IOError:
        os.system("python -m spacy download en_core_web_sm")
        spacy_en = spacy.load("en_core_web_sm")

    spacy_de.tokenizer.add_special_case(u'<s>', [{ORTH: u'<s>'}])
    spacy_de.tokenizer.add_special_case(u'</s>', [{ORTH: u'</s>'}])
    spacy_de.tokenizer.add_special_case(u'<black>', [{ORTH: u'<black>'}])
    spacy_de.tokenizer.add_special_case(u'<unk>', [{ORTH: u'<unk>'}])

    spacy_en.tokenizer.add_special_case(u'<s>', [{ORTH: u'<s>'}])
    spacy_en.tokenizer.add_special_case(u'</s>', [{ORTH: u'</s>'}])
    spacy_en.tokenizer.add_special_case(u'<black>', [{ORTH: u'<black>'}])
    spacy_en.tokenizer.add_special_case(u'<unk>', [{ORTH: u'<unk>'}])


    return spacy_de, spacy_en

# %%
spacy_de, spacy_en = load_tokenizers()

src_vocab, trg_vocab, data = build_vocabulary(spacy_de,spacy_en)
train,val,test = data
src_vocab_size = src_vocab.__len__()
trg_vocab_size = trg_vocab.__len__()
print("Finished preparing data, source vocabulary: {} entries, target vocabulary: {} entries".format(src_vocab_size,trg_vocab_size))

padding_idx = src_vocab.__getitem__("<blank>")


MAX_SEQ_LEN = 30
def pad_to_max(tokens):
    return tokens[:MAX_SEQ_LEN] + ["<blank>"] * max(0, MAX_SEQ_LEN - len(tokens))

def collate_fn(batch):
    # batch = [(<src1>, <trg1>), (<src2>, <trg2>), ...]
    srcs = []
    trgs = []
    for pair in batch:
        src = pair[0]
        trg = pair[1]
        p = tokenize("<s> " + src + " </s>",spacy_de)
        c = src_vocab(p)

        tokenized_src = src_vocab(pad_to_max(tokenize("<s> " + src + " </s>",spacy_de)))
        tokenized_trg = trg_vocab(pad_to_max(tokenize("<s> " + trg + " </s>",spacy_en)))
        
        srcs.append(tokenized_src)
        trgs.append(tokenized_trg)

    srcs = torch.tensor(srcs, dtype=torch.long)
    trgs = torch.tensor(trgs, dtype=torch.long)
    return srcs, trgs

train_dataloader = DataLoader(list(train), batch_size=64, shuffle=True, collate_fn=collate_fn)
val_dataloader = DataLoader(list(val), batch_size=64, shuffle=False, collate_fn=collate_fn)
test_dataloader = DataLoader(list(test), batch_size=64, shuffle=False, collate_fn=collate_fn)
# Out:
# Building German Vocabulary ...
# Building English Vocabulary ...
# Finished preparing data, source vocabulary: 19962 entries, target vocabulary: 11158 entries

# %%
def rate(step, model_size, factor, warmup):
    """
    we have to default the step to 1 for LambdaLR function
    to avoid zero raising to negative power.
    """
    if step == 0:
        step = 1
    return factor * (
        model_size ** (-0.5) * min(step ** (-0.5), step * warmup ** (-1.5))
    )

# %%
from tqdm import tqdm
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Transformer(src_vocab_size, trg_vocab_size, padding_idx = padding_idx,max_length = MAX_SEQ_LEN)
model.to(device)
optimizer = torch.optim.Adam(
        model.parameters(), lr=0.5, betas=(0.9, 0.98), eps=1e-9
    )
lr_scheduler = LambdaLR(
        optimizer=optimizer,
        lr_lambda=lambda step: rate(
            step, model_size=512, factor=1.0, warmup=1000
        ),
    )
loss = nn.CrossEntropyLoss()
max_epoch = 30
best_val_loss = 1e9
for epoch in range(max_epoch):
    train_loss = 0.0
    val_loss = 0.0
    for batch in tqdm(train_dataloader):
        model.train()
        src = batch[0].to(device)
        trg = batch[1].to(device)
        optimizer.zero_grad()
        trg_input = trg[:, :-1]
        ys = trg[:, 1:].reshape(-1)
        logits = model(src, trg_input)
        loss_ = loss(logits.reshape(-1, trg_vocab_size), ys)
        loss_.backward()
        optimizer.step()
        train_loss += loss_.item()
        lr_scheduler.step()

    train_loss /= len(train_dataloader)
    lr = optimizer.param_groups[0]["lr"]
    for i,batch in enumerate(val_dataloader):
        model.eval()
        src = batch[0].to(device)
        trg = batch[1].to(device)
        
        trg_input = trg[:, :-1]
        ys = trg[:, 1:].reshape(-1)
        logits = model(src, trg_input)
        loss_ = loss(logits.reshape(-1, trg_vocab_size), ys) 
        val_loss += loss_.item()
    val_loss /= len(val_dataloader)

    if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), 'saved/model-{0}.pt'.format(val_loss))
    print("Epoch {}, train loss: {}, val_loss: {}, current_lr: {}".format(epoch, train_loss, val_loss, lr))
# Out:
# 100%|██████████| 454/454 [01:01<00:00,  7.42it/s]
# Epoch 0, train loss: 3.0537059230951487, val_loss: 1.810008317232132, current_lr: 0.0003172421443077827
# 100%|██████████| 454/454 [01:01<00:00,  7.40it/s]
# Epoch 1, train loss: 1.686610659313622, val_loss: 1.617099106311798, current_lr: 0.0006344842886155654
# 100%|██████████| 454/454 [01:01<00:00,  7.38it/s]
# Epoch 2, train loss: 1.5004332409556216, val_loss: 1.486424334347248, current_lr: 0.0005987513009682401
# 100%|██████████| 454/454 [01:01<00:00,  7.39it/s]
# Epoch 3, train loss: 1.3343559881664058, val_loss: 1.406144268810749, current_lr: 0.0005185338371874781
# 100%|██████████| 454/454 [01:01<00:00,  7.37it/s]
# Epoch 4, train loss: 1.2001650469943816, val_loss: 1.3636165708303452, current_lr: 0.0004637907634340038
# 100%|██████████| 454/454 [01:01<00:00,  7.35it/s]
# Epoch 5, train loss: 1.082822863094607, val_loss: 1.350212201476097, current_lr: 0.0004233811051589101
# 100%|██████████| 454/454 [01:01<00:00,  7.37it/s]
# Epoch 6, train loss: 0.9736135562611047, val_loss: 1.3588689044117928, current_lr: 0.00039197473702003524
# 100%|██████████| 454/454 [01:01<00:00,  7.34it/s]
# Epoch 7, train loss: 0.8673764309694063, val_loss: 1.3874894976615906, current_lr: 0.000366658792549947
# 100%|██████████| 454/454 [01:01<00:00,  7.37it/s]
# Epoch 8, train loss: 0.7679736329332847, val_loss: 1.4158494025468826, current_lr: 0.0003456892247916521
# 100%|██████████| 454/454 [01:01<00:00,  7.35it/s]
# Epoch 9, train loss: 0.6743433169593895, val_loss: 1.4676295891404152, current_lr: 0.00032794959387586994
# 100%|██████████| 454/454 [01:01<00:00,  7.36it/s]
# Epoch 10, train loss: 0.5893330889782716, val_loss: 1.5180744156241417, current_lr: 0.00031268766891892743
# 100%|██████████| 454/454 [01:01<00:00,  7.37it/s]
# Epoch 11, train loss: 0.5151225890357064, val_loss: 1.5647674351930618, current_lr: 0.00029937565048412007
# 100%|██████████| 454/454 [01:01<00:00,  7.39it/s]
# Epoch 12, train loss: 0.4528150697636709, val_loss: 1.6206425577402115, current_lr: 0.00028763082123731517
# 100%|██████████| 454/454 [01:01<00:00,  7.36it/s]
# Epoch 13, train loss: 0.40311537525464786, val_loss: 1.6784055158495903, current_lr: 0.00027716799460068055
# 100%|██████████| 454/454 [01:01<00:00,  7.37it/s]
# Epoch 14, train loss: 0.3634573796903509, val_loss: 1.7151869013905525, current_lr: 0.00026776972211628414
# 100%|██████████| 454/454 [01:01<00:00,  7.37it/s]
# Epoch 15, train loss: 0.33278053335943936, val_loss: 1.745475947856903, current_lr: 0.0002592669185937391
# 100%|██████████| 454/454 [01:01<00:00,  7.35it/s]
# Epoch 16, train loss: 0.3083986405627843, val_loss: 1.7905724868178368, current_lr: 0.00025152585660950626
# 100%|██████████| 454/454 [01:01<00:00,  7.36it/s]
# Epoch 17, train loss: 0.2898093166592888, val_loss: 1.815447211265564, current_lr: 0.000244439195033298
# 100%|██████████| 454/454 [01:01<00:00,  7.35it/s]
# Epoch 18, train loss: 0.272984097248132, val_loss: 1.8364530801773071, current_lr: 0.0002379196415901674
# 100%|██████████| 454/454 [01:01<00:00,  7.37it/s]
# Epoch 19, train loss: 0.259294811357223, val_loss: 1.8616209924221039, current_lr: 0.0002318953817170019
# 100%|██████████| 454/454 [01:01<00:00,  7.36it/s]
# Epoch 20, train loss: 0.2468863021631598, val_loss: 1.8846192732453346, current_lr: 0.00022630671993405008
# 100%|██████████| 454/454 [01:01<00:00,  7.38it/s]
# Epoch 21, train loss: 0.2373071599111683, val_loss: 1.8904675245285034, current_lr: 0.0002211035710859876
# 100%|██████████| 454/454 [01:01<00:00,  7.36it/s]
# Epoch 22, train loss: 0.22879801533033145, val_loss: 1.903694286942482, current_lr: 0.0002162435584598272
# 100%|██████████| 454/454 [01:00<00:00,  7.45it/s]
# Epoch 23, train loss: 0.2210141707556363, val_loss: 1.9218398407101631, current_lr: 0.00021169055257945504
# 100%|██████████| 454/454 [00:57<00:00,  7.83it/s]
# Epoch 24, train loss: 0.21464804491019984, val_loss: 1.932796649634838, current_lr: 0.00020741353487499126
# 100%|██████████| 454/454 [00:57<00:00,  7.83it/s]
# Epoch 25, train loss: 0.20833056574350936, val_loss: 1.943101480603218, current_lr: 0.00020338570417516115
# 100%|██████████| 454/454 [00:58<00:00,  7.82it/s]
# Epoch 26, train loss: 0.20334299227083308, val_loss: 1.9492912590503693, current_lr: 0.00019958376698941336
# 100%|██████████| 454/454 [00:58<00:00,  7.83it/s]
# Epoch 27, train loss: 0.19924095909763537, val_loss: 1.9737034440040588, current_lr: 0.00019598736851001762
# 100%|██████████| 454/454 [00:58<00:00,  7.82it/s]
# Epoch 28, train loss: 0.1943246356256733, val_loss: 1.9802769050002098, current_lr: 0.0001925786325055462
# 100%|██████████| 454/454 [00:57<00:00,  7.83it/s]
# Epoch 29, train loss: 0.1907908774026165, val_loss: 1.984381079673767, current_lr: 0.00018934178630486195

# %%
def idx_to_word(x, vocab):
    words = []
    for i in x:
        word = vocab.lookup_token(i)
        if '<' not in word:
            words.append(word)
    words = " ".join(words)
    return words

# %%
model.load_state_dict(torch.load("saved/model-1.350212201476097.pt"))
with torch.no_grad():
        for i,batch in enumerate(val_dataloader):
                model.eval()
                src = batch[0].to(device)
                trg = batch[1].to(device)

                trg_input = trg[:, :-1]
                ys = trg[:, 1:].reshape(-1)
                logits = model(src, trg_input)
                for j in range(64):
                        src_words = idx_to_word(src[j], src_vocab)
                        trg_words = idx_to_word(trg[j], trg_vocab)
                        output_words = logits[j].max(dim=1)[1]
                        output_words = idx_to_word(output_words, trg_vocab)

                        print('source :', src_words)
                        print('target :', trg_words)
                        print('predicted :', output_words)
# Out:
# source : Eine Gruppe von Männern lädt Baumwolle auf einen Lastwagen
# target : A group of men are loading cotton onto a truck
# predicted : A woman of men are taking a a a sidewalk
# source : Ein Mann schläft in einem grünen Raum auf einem Sofa .
# target : A man sleeping in a green room on a couch .
# predicted : A man in in a chair chair in a bed .
# source : Ein Junge mit Kopfhörern sitzt auf den Schultern einer Frau .
# target : A boy wearing headphones sits on a woman 's shoulders .
# predicted : A man in headphones sitting in a couch 's shoulders .
# source : Zwei Männer bauen eine blaue Eisfischerhütte auf einem zugefrorenen See auf
# target : Two men setting up a blue ice fishing hut on an iced over lake
# predicted : Two men are up a blue and workers game on a outdoor day .
# source : Ein Mann mit beginnender Glatze , der eine rote Rettungsweste trägt , sitzt in einem kleinen Boot .
# target : A balding man wearing a red life jacket is sitting in a small boat .
# predicted : A man man with a red shirt jacket is holding on front chair chair .
# source : Eine Frau in einem rotem Mantel , die eine vermutlich aus Asien stammende Handtasche in einem blauen Farbton hält , springt für einen Schnappschuss in die Luft .
# target : A lady in a red coat , holding a bluish hand bag likely of asian descent , jumping off the ground for a snapshot .
# predicted : A woman in a red coat , one a saw bag , , a blue men in wearing over a ground and a picture .
# source : Ein brauner Hund rennt dem schwarzen Hund hinterher .
# target : A brown dog is running after the black dog .
# predicted : A man dog runs running on running green dog .
# source : Ein kleiner Junge mit einem Giants-Trikot schwingt einen Baseballschläger in Richtung eines ankommenden Balls .
# target : A young boy wearing a Giants jersey swings a baseball bat at an incoming pitch .
# predicted : A little boy with a red hat is a bat ball from a open pool .
# source : Ein Mann telefoniert in einem unaufgeräumten Büro
# target : A man in a cluttered office is using the telephone
# predicted : A man is a chair restaurant talking cooking art phone
# source : Eine lächelnde Frau mit einem pfirsichfarbenen Trägershirt hält ein Mountainbike
# target : A smiling woman in a peach tank top stands holding a mountain bike
# predicted : A woman woman with a red shirt top holds holding a microphone .
# source : Ein kleines Kind steht allein auf einem zerklüfteten Felsen .
# target : A young child is standing alone on some jagged rocks .
# predicted : A man boy stands standing alone in a sort couch .
# source : Eine Person auf einem Schneemobil mitten im Sprung .
# target : A person on a snowmobile in mid jump .
# predicted : A woman in a jet in a - .
# source : Drei kleine Kinder stehen um ein blau-weißes Fass herum .
# target : Three young children stand around a blue and white barrel .
# predicted : Three men women stand around a large metal white pipe .
# source : Eine Frau sitzt bei ihrem Trockenblumensortiment auf einem Freiluftmarkt .
# target : A woman is sitting by her dried flower display at an outside market .
# predicted : A woman in sitting in her backs steps in on a outdoor park .
# source : Eine Frau spielt ein Lied auf ihrer Geige .
# target : A female playing a song on her violin .
# predicted : A woman in a guitar in a instrument .
# source : Drei Menschen auf zwei Geländemotorrädern und einem Quad fahren durch braunes Gras .
# target : Three people on two dirt - bikes and one four - wheeler are riding through brown grass .
# predicted : Three women are two bikes bikes up on riding riding boys colored , playing a the chairs .
# source : Ein halbnackter Mann schläft draußen auf seinem Stuhl .
# target : A half naked man is sleeping on his chair outdoors .
# predicted : A man dog man is sleeping outside his computer outside .
# source : Eine Gruppe von Menschen steht vor einer Bude auf einem Parkplatz .
# target : A group of people standing in front of a hut in a parking lot .
# predicted : A woman of people are in front of a billboard on a parking lot .
# source : Eine junge Frau fertigt im Regenwald Teppiche an
# target : A young woman is making rugs in the rain forest
# predicted : A group woman is cutting a on a street .
# source : Drei Mädchen , von denen eines gerade trinkt , stehen in einer belebten Straße und schneiden Grimassen .
# target : Three girls make faces as one takes a drink while they stand in a busy street .
# predicted : Three girls are a , a is a drink while a sit in a crowded table .
# source : Ein einzelner Mann in einem schwarzen T-Shirt überragt die anderen Menschen in einer gut besuchten Bar .
# target : A single man in a black t - shirt standing above the crowd at a busy bar .
# predicted : A chef man in a black shirt - shirt is in a street of a bar park .
# source : Frau und Mann gehen über hölzerne Hängebrücke mit Warnschild daneben .
# target : Woman and man walking across wooden rope bridge with a caution sign beside it .
# predicted : Woman in a walking through a steps covered with a billboard advertisement and it .
# source : Ein Mann mit einem Rock hüpft und jongliert dabei mit Messern .
# target : A man in a skirt is jumping while juggling knives .
# predicted : A man in a tank and holding and playing fabric .
# source : Ein asiatisches Mädchen mit grünem Hut und Schürze serviert Getränke auf einem Tablett .
# target : An Asian girl in a green hat and apron is serving drinks on a tray .
# predicted : A old man with a green shirt and a is sleeping a on a machine .
# source : Bauarbeiter stehen auf einer Maschine
# target : Construction workers standing on top of a piece of machinery .
# predicted : A workers are on a of a large of stairs .
# source : Zwei Hunde spielen im hohen Gras mit einem orangen Spielzeug .
# target : Two dogs play with an orange toy in tall grass .
# predicted : Two men run in a orange and in the grass .
# source : Ein süßes Baby lächelt einem anderen Kind zu .
# target : A cute baby is smiling at another child .
# predicted : A man man smiling smiling at a child .
# source : Drei Männer gehen auf einer Straße in den Bergen .
# target : Three men are walking on a road in the mountains .
# predicted : Three men are walking on a street in the city .
# source : Eine Person beim Parasailing über einem großen Gewässer .
# target : A person is parasailing over a large body of water .
# predicted : A woman is shoveling over a body body of water .
# source : Ein Traktor bewegt Erde für den Bau einer Stützmauer .
# target : A tractor is moving dirt to help build up a retaining wall .
# predicted : A man with shoveling through through the by a a wooden bridge .
# source : Ein junges Mädchen läuft allein durch einen Park .
# target : A young girl running by herself in a park .
# predicted : A man girl walking alone a in a park .
# source : Eine Person überquert die Straße und meidet dabei die ausgelaufene Farbe .
# target : A person crosses the street and avoids the spill of paint .
# predicted : A woman in the street while a to street of them .
# source : Kind spielt auf einem Spielplatz und hängt dabei an Stangen .
# target : Child playing on a playground , hanging from bars .
# predicted : A in in a playground with playing up a .
# source : Eine Person in einem roten Langarmshirt liegt auf sehr ungewöhnliche Art auf einer Mauer vor einem Laternenpfahl .
# target : A person wearing a red long - sleeved shirt is lying down on a wall in front of a lamp post in a very unusual manner .
# predicted : A person wearing a red jumpsuit - shirt shirt is laying on on a ladder in front of a large wall and front crowd art time .
# source : Eine Gruppe von Menschen sammelt sich um einen Mann in einem Anzug und einen kleinen Jungen .
# target : A group of people collect around a man in a suit and a little boy .
# predicted : A group of people are from a man in a suit and a suit boy .
# source : Eine Frau sitzt an einer dunklen Bar .
# target : A woman sits at a dark bar .
# predicted : A woman is at a table table .
# source : Menschen gehen auf einem Gehweg , an dem ein Freiluftmarkt stattfindet .
# target : People are walking down a sidewalk where there is an outdoors market .
# predicted : People are walking on a sidewalk in a is a old house .
# source : Ein Mann mit einem blauen Rucksack liest die Zeitung , während er auf die U-Bahn wartet .
# target : A man with a blue backpack reads the paper while waiting to board the subway .
# predicted : A man in a blue backpack and the newspaper while sitting on catch a subway .
# source : Ein großer brauner Hund hält sein Gesicht in den Rasensprenger .
# target : A large brown dog is sticking his face in the sprinkler .
# predicted : A man brown dog is holding out face in the water .
# source : Ein blonder Junge in einem blauen T-Shirt steht lächelnd vor einem Boot aus grünem Nylongewebe .
# target : A blond boy in a blue t - shirt stands smiling before a craft of green nylon fabric .
# predicted : A blond girl in a red shirt - shirt is in to a boat board wood ice toy .
# source : Ein junger weißer Mann fegt eine Veranda mit einem großen Besen .
# target : A young white male is sweeping a porch with a large broom .
# predicted : A man man man is sweeping the wooden with a red tool .
# source : Eine Person wirft gerade eine grüne Bowlingkugel eine Bowlingbahn entlang .
# target : A person about in the middle of throwing a green bowling ball down a bowling lane .
# predicted : A woman in to the middle of a a bowling Frisbee ball into a dirt alley .
# source : Eine Band gibt ein Rockkonzert vor Zuschauern in einer Bar .
# target : A band plays a rock show to a bar audience .
# predicted : A woman is a bass game on a crowd scene .
# source : Ein älterer Mann geht mit einem braunen Hund an einer roten Leine spazieren .
# target : An elderly man is walking a brown dog using a red leash .
# predicted : A old man walking walking down street dog on a brown leash .
# source : Ein Mann fährt ein altmodisches rotes Rennauto .
# target : A man drives an old - fashioned red race car .
# predicted : A man in a orange building covered vehicle vehicle vehicle .
# source : Junge Erwachsene in einer geraden Linie , die rote , gelbe und schwarze T-Shirts tragen , führen einen Sketch auf .
# target : Young adults wearing red , yellow , and black shirts in a straight line perform a sketch .
# predicted : Adults women in a and white , red a , , a yellow room , a concert .
# source : Ein kleiner Junge wirft einen Stein in ruhiges Wasser .
# target : A young boy , throwing a stone into calm water .
# predicted : A man boy throws kicking a ball , the waters .
# source : Zwei kurzhaarige Frauen stehen einander gegenüber und die blonde Frau spricht .
# target : Two women with short hair are facing each other and the blond one is talking .
# predicted : Two men are two hair standing standing each other wearing talking other woman is smiling .
# source : Eine aufwendig kostümierte Figur vor einem prächtig geschmückten Bauwerk .
# target : An elaborate costumed figure is in front of a brightly decorated structure .
# predicted : A old american woman is taking front of a large lit boat .
# source : Ein Hund geht mit einem Tuch im Maul durch einen kleinen Bach .
# target : A dog walking through a small stream with a rag in his mouth .
# predicted : A man with down the plaza building with a stick in the mouth .
# source : Drei kleine Hunde schnüffeln an etwas .
# target : Three small dogs sniff at something .
# predicted : Three women children run in sunset .
# source : Zwei Männer paddeln in einem Kajak einen Fluss mit grünen Bäumen auf beiden Seiten entlang .
# target : Two man are paddling a kayak along a river with green trees on either side .
# predicted : Two men , rowing in boat in a river with trees buildings on them side .
# source : Zwei Mädchen gehen eine Straße entlang .
# target : Two girls walking down the street .
# predicted : Two men are down a street .
# source : Eine Gruppe von Kindern sitzt hinten in einem Van und sieht sich ein Buch an .
# target : A group of kids sitting in the back of a van together looking at a book .
# predicted : A group of children are on a floor of a car while while out a camera .
# source : Strandbesucher blicken auf ein Herz , das von einem Himmelsschreiber am Himmel hinterlassen wurde .
# target : Beach goers look at a heart left in the sky by a sky writer .
# predicted : A workers are at a cake screen in front middle of the rocky window .
# source : Ein Mädchen sitzt in bequemer Haltung an einem öffentlichen Ort und liest ein Buch , das sie mit ihrer Hand geöffnet hält , an der sich ein Ring mit
# target : Sitting casually in a public place , a girl reads holding the book open with her hand on which is a butterfly ring .
# predicted : A girl sitting a blue setting while with park in a a paper and front a feet , the is holding water . .
# source : Ein Mann isst in einem Restaurant zu Mittag .
# target : A man in a restaurant having lunch .
# predicted : A man in a restaurant eating a .
# source : Ein Mann mit Anzug und Brille hält einen Gegenstand in den Händen .
# target : A man in a suit and glass has an object in his hands .
# predicted : A man in a suit and a is a object in the hand .
# source : Ein Mann in einem schwarzen Neoprenanzug surft auf einer Welle .
# target : A man in a black wetsuit is surfing on a wave .
# predicted : A man in a black shirt is paddling a a wave .
# source : Eine Frau mit pinkfarbener Tasche sitzt auf einer Bank .
# target : A woman with a pink purse is sitting on a bench .
# predicted : A woman in pink pink bag is walking on a bench .
# source : Drei Frauen sitzen da und lächeln .
# target : Three women smiling and sitting down .
# predicted : Three women are and laugh down .
# source : Ein rotes Flugzeug fliegt über einem Boot und zieht dabei pinkfarbenen Rauch hinter sich her .
# target : A red plane flying over a boat as it trails pink smoke .
# predicted : A red car flies through the body and he does the bushes .
# source : Ein Mann in einem Klettergurt klettert an einer Felswand
# target : A man in a harness climbing a rock wall
# predicted : A man in a bathing is a tree .
# source : Zwei Bauarbeiter helfen beim Beladen eines Kippers auf einer innerstädtischen Baustelle .
# target : Two construction workers assist in the loading of a dump truck at an urban construction site .
# predicted : Two men workers are are a middle gym a wooden structure on a outdoor outdoor site .
# source : Eine bunt gekleidete Frau geht an einem weißen Lastwagen vorbei , der mit Flaschen gefüllt ist .
# target : A woman in a colorful outfit is walking by a white truck filled with bottles .
# predicted : A military in black black dress walks standing in a white brick that with graffiti .
# source : Eine Frau mit blauem Hut und gelbem Rock springt an einer mit Flieder bewachsenen Stelle in die Luft .
# target : A woman in a blue hat and yellow skirt is jumping in an area with lilacs .
# predicted : A woman in a blue hat and yellow tank is jumping in a air with their .
# source : Ein Mann mit goldfarbener Kleidung steht neben seinem goldfarbenen Fahrrad .
# target : A man is wearing a gold outfit while standing with his gold bike .
# predicted : A man in wearing a blue and is standing next his arms closed .
# source : Baby sieht sich die Blätter am Zweig eines Baumes an .
# target : Baby looking at the leaves on a branch of a tree .
# predicted : A in out the bottom with a tree of a tree .
# source : Eine Reinigungskraft ist im Begriff , eine Bahnstation zu wischen .
# target : A janitor about to mop in a train station .
# predicted : A woman is to jump in the golf station .
# source : Zwei kleine schwarze Jungen spielen mit Plastikflaschen und haben dabei viel Spaß .
# target : Two little black boys are playing with plastic bottles and having a lot of fun .
# predicted : Two women boys boys playing playing with a and and a a conversation of water .
# source : Ampeln schalten auf Grün , während die Menschen sich Motorräder ansehen .
# target : Green traffic signals light up as people look at motorcycles .
# predicted : A and workers , where to a are on night .
# source : Zwei Menschen klettern mit einem Seil an einem Felsen .
# target : Two people are climbing a rock wall with a rope .
# predicted : Two men are climbing a rock with with a boat .
# source : Ein Mann und eine Frau fischen am Strand .
# target : A man and woman fishing at the beach .
# predicted : A man in a are in a beach .
# source : Ein Kind macht einen Rückwärtssalto , während es auf einem Trampolin hüpft .
# target : A child is doing a back flip whilst jumping on a trampoline .
# predicted : A man in doing a trick trick while it off a trampoline .
# source : Kinder fahren in einem Kettenkarussell
# target : Kids are riding a swinging carnival ride
# predicted : A are playing a horse . .
# source : Zwei Menschen halten einen großen umgekehrten Globus mit einem Durchmesser von ca. 120   cm und es wirkt so , als würde ein Kind über die Antarktis springen .
# target : Two people are holding a large upside - down earth globe , about 4 ' in diameter , and a child appears to be jumping over Antarctica .
# predicted : Two people , holding a large heart down down with that , possibly to teenagers , the , as the woman is to be a up a .
# source : Zwei Männer beim Militär spielen Baseball .
# target : Two men in the military are playing baseball .
# predicted : Two men are the middle are playing the .
# source : Eine Frau in einem schwarzen Kleid schiebt einen Wagen mit Thermoskannen einen gepflasterten Fußgängerweg entlang .
# target : A woman in a black dress is pushing a cart with thermos down a paved walkway .
# predicted : A woman in a black shirt is pushing a cart on a on a brick street .
# source : Ein Polizist hält ein Fahrzeug am Straßenrand an .
# target : A policeman stopping a vehicle on the side of the road .
# predicted : A man is a trick while a side of a road .
# source : Mann steht auf einem Pier neben einem Boot an einem ruhigen See .
# target : Man standing on a pier next to a boat on a still lake .
# predicted : Man in on a pier looking to catch boat on a wooded boat .
# source : Eine Gruppe schottischer Offiziere gibt eine Vorführung .
# target : A group of Scottish officers doing a demonstration .
# predicted : A woman of construction workers at a parade .
# source : Eine Frau und ein Kind sitzen zusammen in einem Türrahmen an einem grauen Gehweg , während ein Mann und zwei Frauen vorbeigehen .
# target : A woman and a child sit together in a door frame along a gray sidewalk , as a man and two women walk past .
# predicted : A woman and a child sit on in a hospital with in a gray sidewalk while while a man and two women walking down .
# source : Ein einzelner Feuerwehrmann hilft bei der Bekämpfung eines großen Brandes .
# target : A lone firefighter helps tame a large fire .
# predicted : A man man cutting a a man fish .
# source : Eine Person in einem lilafarbenen Oberteil malt ein Bild von einer Frau auf eine weiße Wand .
# target : A person with a purple shirt is painting an image of a woman on a white wall .
# predicted : A person in a purple shirt and painting a image of a woman on a white wall .
# source : Ein kleines Mädchen liegt auf dem Boden , während ihre jüngere Schwester Krankenschwester spielt .
# target : A small girl is lying on the floor while her younger sister is pretending to be a nurse .
# predicted : A little child is laying on a floor while a friend wife prepares getting to be a picture .
# source : Eine junge Frau und eine ältere Frau in traditionellen Saris spinnen Textilien , während drei weitere Personen in moderner Kleidung nur von der Taille abwärts auf dem Bild zu
# target : A young woman and older woman wear traditional saris as they spin textiles , three people are pictured at only the waists , and wear modern clothes .
# predicted : A young woman and a woman are a garb are a stand a and while people in in and the the same of with the a flags .
# source : Frauen gehen durch den Tiefschnee einen steilen Abhang hinunter .
# target : Women walking through deep snow and down a steep hill .
# predicted : Women in down the water - splashing a dirt path .
# source : Der FedEx-Fahrer hört dem Arbeiter mit dem grünen Schutzhelm zu , während die zu versendende Ausrüstung eingeladen wird .
# target : The FedEx driver listens to the workman in the green hard hat while the equipment to ship is being loaded .
# predicted : The Houston basketball having to the field with front green , while while the defender is the between coming played .
# source : Der braune Hund trägt ein schwarzes Halsband .
# target : The brown dog is wearing a black collar .
# predicted : The man dog is carrying a black collar .
# source : Ein braun-weißer Hund rennt eine gelb-blaue Rampe hinunter .
# target : A brown a white dog runs down a yellow and blue ramp .
# predicted : A man and black dog runs down a ramp covered blue bike .
# source : Ein Kind macht sich bereit , ein Buch zu lesen .
# target : A child is getting ready to read a book .
# predicted : A man in getting ready to make a book .
# source : Ein älterer Japaner versucht , eine kleine rot-graue Maschine zu reparieren .
# target : A older Japanese man trying to fix a small red and gray machine .
# predicted : A man man player tries to hit a small machine device yellow truck .
# source : Ein kleines Kind und eine Frau stehen um einen Hahn im Käfig herum .
# target : A young child and a woman are standing around a caged rooster .
# predicted : A man man and a young are standing around a wooden game .
# source : Ein als Spiderman verkleidetes Kind klingelt an der Tür .
# target : A child that is dressed as Spiderman is ringing the doorbell .
# predicted : A man in is cutting up a team hanging the subway .
# source : Ein braun gekleideter Mann hält ein Lichtschwert .
# target : A man dressed in brown holding a light saber .
# predicted : A man is man black is a large truck .
# source : Eine junge Frau singt in ein Mikrofon , während ein Mann hinter ihr eine Gitarre hält .
# target : A young woman stands singing at a microphone while a man behind her holds a guitar .
# predicted : A young woman is in into a microphone while a man stands her on her microphone .
# source : Zwei Kinder graben Löcher in die Erde .
# target : Twp children dig holes in the dirt .
# predicted : Two divers are up on the ice .
# source : Viele Stühle sind leer und nur einige wenige Menschen genießen die Sonne .
# target : Many of the chairs are empty with only a few people enjoying the sun .
# predicted : Many people people steps and holding and some some few people in the camera .
# source : Einige Männer sitzen in einem Boot in der Nähe eines Strandes , der mit gestapelten Holzstämmen und Stöcken bedeckt ist .
# target : Some men are sitting on a boat near a beach covered in stacked logs and sticks .
# predicted : Several men are sitting in a boat near a fence near in a water and blankets .
# source : Ein junger Mann trägt etwas in einem großen schwarzen Plastikmüllsack .
# target : A young man is carrying something in a large black plastic garbage bag .
# predicted : A man boy is wearing a on front large black chair white car .
# source : Ein älterer , übergewichtiger Mann wendet einen Pfannkuchen , während er Frühstück macht .
# target : An older , overweight man flips a pancake while making breakfast .
# predicted : A old man male man and down bucking being a something .
# source : Männer in gelben Anzügen und ein Klavier befinden sich auf der Bühne und ein Mann spielt einen Kontrabass .
# target : Men wearing yellow suits are on stage with a piano and one man is playing an upright bass .
# predicted : Men in white and and wearing a in a red and the man playing playing a instrument game .
# source : Mehrere Menschen stehen in der Dämmerung in der Nähe einiger Bäume .
# target : Several people are standing near trees at dusk .
# predicted : Several people are standing near a and night .
# source : Ein brauner Hund kaut auf einem großen Holzstück herum .
# target : A brown dog chewing on a large piece of wood .
# predicted : A man and is on a brown wooden of wood .
# source : Ein Wanderer posiert für ein Foto in einer trockenen Berglandschaft .
# target : A hiker posing for a photo in an arid mountain landscape .
# predicted : A man is for a picture with a orange setting setting .
# source : Eine Gruppe von Kindern spielt im Wasser unter einer Brücke .
# target : A group of children play in the water under a bridge .
# predicted : A woman of children play in the water under a fountain .
# source : Eine Frau lächelt neben einem Mann , der ebenfalls lächelt und eine Zuckerwatte hält .
# target : A woman is smiling next to man who is also smiling while holding cotton candy cone .
# predicted : A woman in smiling next to a sitting is wearing wearing and wearing a a behind .
# source : Zwei Frauen stehen vor einer Schulklasse und sprechen über ein Buch .
# target : Two women are standing in front of a class of children talking about a book .
# predicted : Two men are standing in front of a table talking people are on a microphone .
# source : Zwei brünette Frauen sprechen vor einer Klasse voll mit blonden Kindern .
# target : Two brunette women talking to a classroom full of blond children .
# predicted : Two men women are in each man outside of people children .
# source : Eine Person mit Hut und Schal blickt nach rechts .
# target : A person wearing a hat and scarf looks to the right .
# predicted : A woman in a hat and a looking at the camera .
# source : Zwei Menschen überqueren eine Straße .
# target : Two people walking across a street .
# predicted : A men are down a street .
# source : Ein alter Mann hält einen Hund empor , während sein anderer Hund auf seinen Schoß klettert .
# target : An old man is holding up one dog while his other dog climbs on his lap .
# predicted : An old man holds holding a a of while a other dogs on on a skateboard .
# source : Drei Kinder sehen zu , wie ein Mann auf einer Bühne Gitarre spielt .
# target : Three children watch a man on stage playing guitar .
# predicted : Three women are a man in a a a .
# source : Ein Junge übernimmt bei einem Rennen einen Stab von einem Mädchen .
# target : A boy who is taking a stick from a girl in the middle of a race .
# predicted : A man in is making a nap of a piece 's a middle of a crowd .
# source : Ein blauer Jeep fährt in tiefes , schlammiges Wasser .
# target : A blue Jeep drive into deep , muddy water .
# predicted : A man car air in the in grassy field .
# source : Die Frau mit einem schwarzen Hut macht ein Foto bei Schneefall .
# target : The lady wearing a black hat is taking a picture while the snowfalls .
# predicted : The woman is a black hat is taking a picture of a crowd .
# source : Ein Mann sitzt auf dem Boden und spielt Gitarre .
# target : A man sitting on the ground , playing guitar .
# predicted : A man in on the floor in playing the .
# source : Ein Hund geht durch eine seichte Wasseransammlung , die sich an einem felsigen Berghang befindet .
# target : A dog treads through a shallow area of water located on a rocky mountainside .
# predicted : A dog with through a city street that a that on a rocky path .
# source : Eine junge Asiatin vollführt in einem belebten Stadtteil einen Luftsprung .
# target : A young Asian woman is jumping midair in a crowded city part .
# predicted : A woman woman band is performing into in a busy Asian street .
# source : Eine Drei-Mann-Band tritt auf einer Bühne auf .
# target : A three man band is performing on stage .
# predicted : A woman men is performing performing on stage .
# source : Vier Menschen protestieren gegen die Behandlung junger Arbeiter durch Equinox .
# target : Four people are protesting the treatment of young workers by Equinox .
# predicted : Four men are hanging against side of a race in festival .
# source : Ein Mann brät Burger auf einem schwarzen Grill .
# target : A man cooking burgers on a black grill .
# predicted : A man in on on a large grill .
# source : Ein Mann mit einer roten Baseballkappe lehnt an einem Laternenpfahl .
# target : A man in a red baseball cap is leaning against a light pole .
# predicted : A man in a red jacket cap leans leaning on a building chair .
# source : Ein kleiner Junge in einem gelben T-Shirt hängt an einem Ring und ist dabei von anderen Kindern umgeben .
# target : A young boy in yellow t - shirt hanging from a ring with other kids around .
# predicted : A little boy in a shirt - shirt is on a white and a children watch .
# source : Ein kleines Kind isst Obst und trinkt ein Glas Saft .
# target : A small child eating fruit and drinking a glass of juice .
# predicted : A man child is a on eating beer glass of beer .
# source : Ein Mann und zwei Frauen in Shorts gehen die Straße entlang .
# target : One man and two women wearing shorts , walk down the street .
# predicted : A man in two women are white walking walking down the street .
# source : Zwei Pudel rennen durch den Schnee .
# target : Two poodles are running through the snow .
# predicted : Two men are running through the woods .
# source : Ein kleines rothaariges Mädchen in einem Spidermananzug reitet auf einem Spielzeugpferd .
# target : A little redheaded girl wears a Spider - Man suit while riding a play horse .
# predicted : A man girl girl wearing a red outfit colored riding , a a tennis baseball .
# source : Mann in einem kleinen weißen Boot auf einem See .
# target : Man in a small white boat on a lake .
# predicted : Man in a small white dog with a skateboard .
# source : Die Skier befinden sich vor der Hütte .
# target : The skiers are in front of the lodge .
# predicted : The woman are in the of the park .
# source : Menschen werden beim Klettern oder Wandern fotografiert .
# target : People are being photographed while mountain climbing or hiking .
# predicted : People are walking arts on climbing on a slide .
# source : Einige Menschen schwimmen in einem Gewässer .
# target : Several people swim in a body of water .
# predicted : A people are workers a pool of water .
# source : Frauen in Strandbikinis spielen Volleyball bei sonnigem Wetter .
# target : Women in beach bikinis play volleyball in the sunny weather .
# predicted : Women in uniform outfits are in in the same time .
# source : Ein Mann und eine Frau sitzen einander gegenüber an einem Restauranttisch .
# target : A man and woman sit across from each other at a restaurant table .
# predicted : A man in a are on the each other in a sports scene .
# source : Eine Mutter und zwei Kinder posieren mit lustigen Gesichtern .
# target : A mother and two children are posing with funny faces .
# predicted : A woman and two children are sitting for a umbrellas .
# source : Ein Golden Labrador schwimmt mit einem roten Spielzeug im Maul durch das Wasser .
# target : A Golden Labrador is swimming through water with a red toy in its mouth .
# predicted : A man diver with swimming with a with a red toy in the mouth .
# source : Vier Männer stehen bei einem gelben Auto .
# target : Four men standing near a yellow car .
# predicted : Four women are around a wooden sign .
# source : Eine Gruppe von Männern , Frauen und Kindern , die alle Hüte tragen , unterhält sich am Strand .
# target : A group of men , women , and children , all wearing hats , talk on the beach .
# predicted : A group of men , women , one children , one wearing red , are , the phone .
# source : Kleiner Junge im Tarnanzug krabbelt auf braunem Fußboden
# target : Little boy in Cami crawling on brown floor
# predicted : Young boy in the gear in a outfit
# source : Ein kleines Mädchen spendet an einer Ladenfront mit weißen Plastikbehältern für die Heilsarmee .
# target : A little girl donates to the Salvation Army near a storefront with white , plastic containers .
# predicted : A man girl is a a camera people with a body with the and and balloon .
# source : Ein gelber Hund am Strand trägt einen Ball im Maul .
# target : A yellow dog carries a ball in its mouth on the beach .
# predicted : A man dog is a ball on the mouth on a beach .
# source : Ein Mann in einem roten T-Shirt steht mit zwei Mädchen vor einem alten Bauwerk .
# target : A man in a red shirt is standing with two fitls in front of an old structure .
# predicted : A man in a red shirt is standing with two men in front of a outdoor building .
# source : Mann sieht einer Frau in einer Bar beim Sprechen zu .
# target : Man looks on as woman is talking while at a bar .
# predicted : Man in on a a in wearing and a a woman .
# source : Eine Band spielt auf einer Freilichtbühne am Fluss .
# target : A band playing in an outdoor theater , along the river .
# predicted : A woman is a a acoustic site on on the river .
# source : Zwei Frauen lächeln bei einer Veranstaltung .
# target : Two women are smiling at an event .
# predicted : Two men are smiling at a event .
# source : Ein Frau in einer rosafarbenen Bluse zeigt einem Mann in einem gestreiften Pullover , wie eine Handarbeit aus Garn hergestellt wird .
# target : A woman wearing a pink shirt showing a man with a striped sweater how to do some work with yarn .
# predicted : A woman in a pink shirt and a man in a striped sweater , round be a sort from it .
# source : Ein Kind sitzt auf einer Gesteinsformation .
# target : A child sitting on a rock formation .
# predicted : A man is on a rock looking .
# source : Ein Mann sitzt mit einem Bier in der Hand auf einem Stuhl und brät an einem Holzstab etwas zu essen .
# target : A man sitting on a chair with a beer in his hands roasting something to eat on a wooden stick .
# predicted : A man in on a table with a large and her mouth and on on a a a table table .
# source : Ein Polizist in Uniform trägt einen Ohrhörer .
# target : A police officer in his uniform wearing an ear piece .
# predicted : A man officer in a clothing is only orange costume .
# source : Ein Mann in Feuerwehrkleidung überquert die Straße bei einem weißen Bus und einem roten Sattelschlepper .
# target : There is a man in fireman 's gear crossing the road near a white bus and a red semi .
# predicted : A is a man in a , clothes , a street and a bus bus that a blue building .
# source : Ein schwarzer und ein weißer Hund schwimmen im klaren Wasser .
# target : A black and white dog swimming in clear water .
# predicted : A man dog a dog are in the water .
# source : Eine Band spielt bei einem Konzert Musik auf einer Bühne .
# target : A band is playing music on stage at a concert .
# predicted : A woman is playing a game a with a party .
# source : Drei Menschen spielen Musikinstrumente und eine andere Person sieht so aus , als ob sie singen würde .
# target : There are 3 people playing musical instrument and one other person looks like she is singing .
# predicted : Three are people people , musical instruments and one is is , at he is singing .
# source : Ein Mann spielt Keyboard und singt in ein Mikrofon .
# target : A man playing a keyboard and singing into a microphone .
# predicted : A man in a keyboard while singing into a microphone .
# source : Ein kleiner Junge springt in das Wasser .
# target : A young boy jumps into water .
# predicted : A man boy jumping in the .
# source : Eine Frau liest eine Karte und sitzt dabei auf der Kante eines Sofas , während eine andere Frau mit einem Trinkglas in der Hand neben ihr steht .
# target : A woman is reading a card while sitting on an end of a couch , while another woman is standing next to her holding a glass to drink .
# predicted : A woman is reading a newspaper and sitting on the obstacle of a boat while while another woman with using in to her . a bike . her .
# source : Bauarbeiter arbeiten hart an einem Bauvorhaben .
# target : There are construction workers working hard on a project .
# predicted : Construction are construction workers are on at the street .
# source : Ein Mann rasiert sich , während er am Strand vor dem Meer sitzt .
# target : A man is shaving while sitting on the beach in front of the ocean .
# predicted : A man in showing as a on the beach is front of the ocean .
# source : Eine blonde Frau in einem blauen T-Shirt packt eine Mütze aus .
# target : A blond - haired woman wearing a blue shirt unwraps a hat .
# predicted : A woman woman haired woman in a white shirt is is flip .
# source : Zwei Männer unterhalten sich hinter einer Orgel , während rechts eine einzelne Frau steht .
# target : Two men talk to each other behind an organ while a lone woman stands to their right .
# predicted : Two men , behind each other while a airport stand a woman woman is in the faces .
# source : Ein junger Mann mit blondem Haar spricht in ein Mikrofon .
# target : A young blond - haired man speaks into a microphone .
# predicted : A man girl man haired man wearing into a microphone .
# source : Ein Hoteldiener in einem Mantel schiebt eine Ladung Gepäck .
# target : A motel valet man wearing a trench coat pushing a load of luggage .
# predicted : A man is in in a coat , , a bicycle of wood .
# source : Hund kauert zwischen Pflanzen , um Kamera anzusehen .
# target : Dog in plants crouches to look at camera .
# predicted : Dog running a with in each lot camera .
# source : Eine Gruppe spielt vor einer Menschenmenge Musik auf einer Bühne .
# target : A group is playing music on stage in front of a crowd of people .
# predicted : A woman of playing a in the with front of a crowd of people .
# source : Drei Hunde spielen im Schnee .
# target : Three dogs playing in the snow .
# predicted : A people run in the water
# source : Ein Mann und eine Frau unterhalten sich , während sie neben einem Baum stehen .
# target : A man and a woman talk while standing next to a tree .
# predicted : A man in a woman are on a in to a tree .
# source : Ein Hund springt einem gelb-schwarzen Ball hinterher .
# target : A dog jumps for a yellow and black ball .
# predicted : A man is a a jump ball white ball .
# source : Eine ältere Dame in einem grau-roten Pullover kocht eine Mahlzeit .
# target : An older lady in a gray and red sweater is cooking on a meal .
# predicted : A old woman in a gray shirt white sweater is eating on a stage .
# source : Frau im Mantel bei Schneefall vor einem Haus
# target : Woman in coat outside a house while snowing
# predicted : Woman in red at of food food standing
# source : Eine Frau trägt eine andere Frau mit gleicher Sportkleidung auf ihrem Rücken .
# target : A woman carrying another woman wearing matching exercise attire on her back .
# predicted : A woman in a woman is a the clothing on the back .
# source : Ein Kind steht neben einem Kinderwagen und hält ein Spielzeugschwert .
# target : A child standing by a stroller and holding a toy sword .
# predicted : A man in by a car and holding a wooden baby .
# source : Ein Typ mit lockigem Haar fährt mit dem Skateboard eine graue Rampe mit gelben Buchstaben entlang .
# target : A guy with curly hair is skateboarding along a gray ramp with yellow letters .
# predicted : A guy in blond hair is riding down a path and with a skateboard .
# source : Ein Mann rollt einen runden Tisch über den Boden .
# target : A man is rolling a circular table across the floor .
# predicted : A man in practicing a round instrument on the path .
# source : Eine Gruppe von Menschen in einem Boot auf einem großen Gewässer .
# target : A group of people are in a boat on a large body of water .
# predicted : A woman of people in in a boat on a body body of water .
# source : Ein Mann in einem gelben Hemd steht auf dem Gehweg und nimmt Messungen vor .
# target : A man in a yellow shirt is standing in the sidewalk measuring .
# predicted : A man in a yellow shirt is standing on the metal cheering .
# source : Eine Frau in einer blauen Bluse und Jeans wirft etwas in einen Müllcontainer .
# target : A woman in a blue shirt and jeans is throwing something away in a dumpster .
# predicted : A woman in a blue shirt is jeans is throwing a into into a truck .
# source : Eine Frau mit einer Domino-Maske und streng frisiertem Haar auf einer Party .
# target : A woman in a domino mask and severe hair is at a party .
# predicted : A woman in a bonnet - is khaki hair is playing a party .
# source : Eine Person beim Parasailing auf einem Wellenkamm .
# target : A person parasails on the crest of a wave .
# predicted : A group is school a beach of a lake .
# source : Männer in blauer Spielkleidung sitzen in einem Bus .
# target : Men wearing blue uniforms sit on a bus .
# predicted : Men in uniform soccer sit on a bus .
# source : Ein Geländewagen versucht , aus einem Graben herauszukommen .
# target : An ATV attempts to get out of a ditch .
# predicted : A old rider to block off a dust pipe .
# source : Ein Mann greift bei einem Footballspiel einen anderen Mann an .
# target : A man tackles another man while playing football .
# predicted : A man in a man in wearing a .
# source : Ein rot-weiß gekleideter Footballspieler spricht mit einem Trainer .
# target : A football player in red and white is talking to a coach .
# predicted : A man player in black is white is doing to a crowd .
# source : Zwei Mädchen sitzen an einer Mauer und sehen bei einer Sportveranstaltung zu .
# target : Two girls sit near a wall and watch a sporting event .
# predicted : Two men are at a counter with watching a wooden event .
# source : Ein Mann , der zum Trainerstab von OU gehört , trägt während eines Footballspiels eine Sonnenbrille auf dem Kopf .
# target : A man on the coaching staff for OU has sunglasses on his head during a football game .
# predicted : A man in a patio of is the , their , a cellphone while a stage game .
# source : Dieses Footballteam trägt rote Trikots und rote Helme .
# target : This football team wears red shirts and red helmets .
# predicted : The picture player is a jerseys and red hat .
# source : Ein schwarz gekleideter Junge schlägt ein Rad am Strand .
# target : A boy in black clothes is doing a cartwheel on the beach .
# predicted : A man in black is is swinging a trick on the beach .
# source : Sie posieren für ein Bild .
# target : They are posing for a picture .
# predicted : A are playing for a picture .
# source : Ein Mann mit einem grünen Shirt küsst ein weinendes Kleinkind und sieht dabei den Läufern eines Straßenrennens zu .
# target : A man in a green shirt is kissing a crying toddler whilst watching runners in a road race .
# predicted : A man in a green shirt and carrying a toddler baby while looking a look a race race .
# source : Fünf Mitglieder einer Band spielen ein Lied .
# target : Five members of a band are playing a song .
# predicted : Five people of a band are playing a game .
# source : Drei Frauen sitzen mit einem Baby auf einer Decke auf dem Boden , unterhalten sich und haben Spaß zusammen .
# target : Three women are sitting on a blanket on the ground with a baby , and are talking and having a good time .
# predicted : Three women , sitting in a bench and a grass with a man standing and some playing to are a conversation time .
# source : Ein Mann und ein Junge sitzen an einem Altar und halten beide eine Glocke .
# target : A man and a boy are sitting at an altar both are holding bells .
# predicted : A man in a boy are sitting on a open with holding holding a .
# source : Ein Mann mit Sonnenbrille hilft einem Kind mit Sonnenbrille eine Rutsche herunterzurutschen .
# target : A man with sunglasses is helping a child with sunglasses slide down a slide .
# predicted : A man in sunglasses is holding a child in a in in a boardwalk .
# source : Ein Hund rennt durch das Gras auf die Kamera zu .
# target : A dog runs through the grass towards the camera .
# predicted : A man with through the water near the camera .
# source : Das Mädchen mit dem langen Pferdeschwanz ist bereit , den Ball einer anderen Spielerin auf dem Spielfeld zuzuwerfen .
# target : The girl with the long ponytail prepared to throw the ball to another player on the field .
# predicted : The girl in the long hair is for catch the ball from another player on the field .
# source : Zwei Männer ringen auf einem gelb-blauen Boden .
# target : Two man are wrestling on a yellow and blue floor .
# predicted : Two men are wrestling on a stage and blue floor .
# source : Ein Mädchen in einem rot-weißen T-Shirt und blauen Shorts macht sich bereit , einen Ball zu werfen .
# target : A girl in a red and white shirt and blue shorts is getting ready to throw a ball .
# predicted : A girl in a red and white shirt and blue shorts is getting ready to hit a ball .
# source : Ein sitzender Mann arbeitet mit seinen Händen .
# target : A seated man is working with his hands .
# predicted : A man man is working on a hands .
# source : Ein brauner Hund rennt mit einem Stock im Maul über den Sand .
# target : A brown dog runs on the sand carrying a stick .
# predicted : A man dog runs through the grass with a stick .
# source : Eine Person rudert in ihrem Boot im Wasser .
# target : A person rowing in their boat in the water .
# predicted : A woman is in her hands in the water .
# source : Ein Mann in einem rot-weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog-Stand .
# target : A man in a red and white striped shirts sits on a stool at a hotdog stand .
# predicted : A man in a red and white striped shirt sitting on a chair in a computer table .
# source : Ein Mann fotografiert weiße und gelbe Tulpen .
# target : A man takes pictures of white and yellow tulips .
# predicted : A man is a of a and white outfit .
# source : Zwei Männer mit Fesen sprechen miteinander auf einem Freiluftmarkt .
# target : Two men in Fez 's have a discussion in an outdoor market .
# predicted : Two men are a are are their sidewalk on a open park .
# source : Mann und Junge spielen bei Sonnenuntergang mit einem Hund am Strand .
# target : Man and boy play with dog at sunset on a beach .
# predicted : Man in women playing in a in a with the beach .
# source : Ein Heißluftballon landet mit dem Schatten eines Mannes im Hintergrund .
# target : A hot air balloon touching down with a man 's shadow in the background .
# predicted : A man brown car rider a a a man in mouth in the background .
# source : Dieser Mann trägt eine weiße Kappe oder Mütze .
# target : This man is wearing a white cap or hat .
# predicted : This man is wearing a white jacket , hat .
# source : Eine Frau lässt sich ein Tattoo im Gesicht machen , das aus schwarzen Linien und Glitter besteht .
# target : A female getting a face tattoo of black lines and glitter .
# predicted : A woman in a baby of on a and into white .
# source : Ein kleines Kind mit Jeanshut spielt in einem Reifen .
# target : A toddler in a denim hats plays in a tire .
# predicted : A man is a baseball jacket is in a pool .
# source : Eine Menschenmenge steht auf der Straße vor einer Reihe weißer Zelte .
# target : A crowd of people stand in street in front of a series of white tents .
# predicted : A woman of people are on the in front of a crowd of green buildings .
# source : Eine Menschenmasse geht durch den Park .
# target : A mass of people walk through the park .
# predicted : A group school people walking through the rain .
# source : Eine dunkelhaarige Frau mit einer blauen Bluse und Sonnenbrille hält ein Spruchband , während ein junges Mädchen mit geflochtenem Haar auf das Spruchband schreibt .
# target : A dark - haired woman wearing a blue blouse and sunglasses holds a banner while a young girl with braided hair writes on the banner .
# predicted : A dark - haired woman wearing a blue shirt and a , a gun while a young girl with tattoos hair is on the roof .
# source : Viele asiatische Kinder bilden einen Zug unter einem Vietnam-Schild .
# target : Many asian children made a train under a viet nam sign .
# predicted : Many people people are up small , a tree colored tree .
# source : Ein Cowboy versucht bei einem Rodeo , ein Pferd zu bändigen , während das Pferd nach hinten ausschlägt
# target : A cowboy wrangling a horse in a rodeo as the horse does a back kick
# predicted : A cowboy in a trick while a horse is a horse passes a trick .
# source : Eine Braut und ein Bräutigam bei ihrem Hochzeitskuss
# target : A bride and a groom at their wedding kissing
# predicted : A woman and a man are a wedding .
# source : Zwei Mitarbeiter des Notfallschutzes legen Klötze unter einen Zug .
# target : Two emergency response workers are putting blocks underneath a train .
# predicted : Two men workers the are picking out under a tree .
# source : Mann arbeitet an den Schienen in einem Bahnhof .
# target : Man working on the railroad in a railroad station .
# predicted : Man in on the platform platform a train train .
# source : Ein paar Bauarbeiter , in Schubkarren wird Beton gemischt , sie bauen oder reparieren eine Wand und die Wand ist noch nass .
# target : Some construction workers , there is concrete being mixed in wheelbarrows , they are building or repairing a wall , the wall is wet still .
# ...
# source : Kleines Kind in einem grünem Shirt putzt sich unter Mamas Aufsicht mit einer gelben Zahnbürste die Zähne .
# target : Toddler in a green shirt is brushing his teeth with a yellow toothbrush , while being supervised by mom .
# predicted : Young in a green shirt and standing something teeth near a red toy in and wearing lifted by them .
# source : Ein Mann in einem Rollstuhl und einem roten Jogginganzug trägt eine Fackel .
# target : A man in a wheelchair and wearing a red jogging suit is carrying a torch .
# predicted : A man in a wheelchair is a a red sweater shirt in walking a crowd .
# source : Ein Sohn und seine Eltern nehmen ein Gruppenfoto in einer Kirche auf .
# target : A son and his parents are taking a group picture in a church .
# predicted : A man and his player are posing a picture of in front church .
# source : Drei Männer treten bei einem Hürdenlauf gegeneinander an .
# target : Three men competing in a hurdle race .
# predicted : Three women are in a game race .
# source : Zwei Männer beobachten einen anderen , während dieser am nassen Zement letzte Hand anlegt .
# target : Two men are observing another as he puts the finishing touches on wet cement .
# predicted : Two men are watching another man a is the lid a the the slide .
# source : Ein Soldat blickt durch ein Fernglas in die Berglandschaft .
# target : A soldier is looking at binoculars into the mountainous landscape .
# predicted : A man in looking through a at the camera area .
# source : Eine Gruppe von kleinen Jungen macht einen Wettlauf an einem verschneiten Tag .
# target : A group of young boys race on a snowy day .
# predicted : A woman of young boys are and a dirt day .
# source : Ein Mann übt Seilspringen , während ihm eine Menschenmenge dabei zusieht .
# target : A man jumps rope while a crowd of people watch him .
# predicted : A man in over while a man of people in him .
# source : Ein kleiner Junge und ein Mädchen lachen miteinander , während das Mädchen ein Handzeichen macht .
# target : A young boy and girl are laughing together as the girl holds up a hand sign .
# predicted : A little boy and a are playing and , a girl is a a girl trick .
# source : Zwei Männer aus gegnerischen Teams rennen in Richtung eines Fußballs .
# target : Two men on opposing teams race toward a soccer ball .
# predicted : Two men are the teams are and the soccer game .
# source : Ein Fahrradfahrer in einem gelben Shirt vollführt ein unglaubliches Kunststück in der Luft .
# target : A biker wearing a yellow shirt pulls of an incredible trick in the air .
# predicted : A man in a yellow shirt is a a orange animal in the air .
# source : Zwei Kickboxerinnen , von denen eine einen lilafarbenen Sport-BH trägt , kämpfen in einer Arena .
# target : Two female kickboxers , one with a purple sports bra , battle it out in an arena .
# predicted : Two teenagers athletes , one of a purple outfit match , are a in in a arena .
# source : Zwei Männer auf schnellen Motorrädern sausen auf einer Rennstrecke um eine Kurve .
# target : Two men on fast motorcycle speeding around a corner on a racetrack .
# predicted : Two women are stilts bikes are gear on dirt in a track .
# source : Zwei Männer decken den Mann mit dem Basketball während eines Spiels in der Dämmerung ab .
# target : Two men guard the man with the basketball during a game at dusk .
# predicted : Two men are , man is a basketball game a game in dusk .
# source : Ein Mann mit Reitstiefeln und einem Helm reitet auf einem weißen Pferd und das Pferd springt über ein Hindernis .
# target : A man wearing riding boots and a helmet is riding a white horse , and the horse is jumping a hurdle .
# predicted : A man in a a and a bicycle is riding a white and and jumping a other is jumping over jump .
# source : Eine Gruppe von Männern in Kostümen spielt Musik .
# target : A group of men in costume play music .
# predicted : A woman of men in a and together .
# source : Ein Mann und mehrere Frauen sehen Milchkästen voll mit Schallplatten oder Bildern durch , die zum Verkauf stehen .
# target : Man and women look through milk crates full of records or pictures on sale .
# predicted : A in women , at a women of of medical with taking on them .
# source : Ein Rennkatamaran wird im Wasser auf einen Rumpf gehoben .
# target : A racing catamaran is lifted onto one hull in the water .
# predicted : A man bike is being out a of in the pool .
# source : Eine Gruppe von Marinesoldaten geht mit amerikanischen Flaggen und anderen Militärflaggen die Straße entlang .
# target : A group of marines walking down the road with american flags and other military flags .
# predicted : A group of bicyclists walk down a street with flags flags in a carrying people .
# source : Ein Mann hält der Kamera ein Trinkglas entgegen .
# target : A man holding a drinking glass at the camera .
# predicted : A man in the camera up of the camera .
# source : Ein Mann auf einer Bühne spielt Gitarre mit Leuchten im Hintergrund .
# target : One man on stage , playing a guitar with lights in the background .
# predicted : A man is a , a guitar guitar with a in the background .
# source : Vier kleine Kinder spielen mit leeren Behältern .
# target : Four young kids playing with empty canisters .
# predicted : Four women women play in a pool .
# source : Eine Gruppe von Arbeitern hört den Anweisungen eines Kollegen zu .
# target : A group of workers are listening to instruction from a colleague .
# predicted : A woman of workers are listening to a a a court .
# source : Ein Shriner fährt bei einer Parade auf einem großen grünen Traktor die Straße entlang .
# target : A shriner rides a large green tractor down the road during a parade .
# predicted : A fisherman skier a bicycle wave bike on on side on a parade .
# source : Drei Hunde spielen im Wasser .
# target : Three dogs are playing in the water .
# predicted : A people run playing in the water .
# source : Ein Mann schlägt die Trommel und ein kleiner Junge schlägt seine eigene , kleine Trommel .
# target : A man plays a drum and a little boy hits his own , little drum .
# predicted : A man in the drums while the small boy in a friend piece white children .
# source : Eine Gruppe von Mädchen spielt ein Spiel zu Pferd .
# target : A group of girls playing a game on horseback .
# predicted : A woman of girls playing in game together stage .
# source : Ein Mann sieht zu , wie eine Frau an einem Schießstand lächelnd eine Pistole abfeuert .
# target : A man watching as a woman fires a gun with a smile at a firing range .
# predicted : A man in a a man in a woman on a crowd in the video machine .
# source : Der führende Radfahrer strampelt um sein Leben , als konkurrierende Länder von hinten aufschließen .
# target : The bike leader pedals for his life as competing countries gain his tail .
# predicted : The University rider rider down the race race the player is the teeth .
# source : Ein Team von Fußballspielern steht zusammengedrängt und hat eine ernsthafte Diskussion .
# target : A team of soccer players is huddled and having a serious discussion .
# predicted : A man of cheerleaders players stand standing in one a large flip .
# source : Eine Gruppe von Menschen in lilafarbenen T-Shirts und hellbraunen Hosen geht gemeinsam in dieselbe Richtung .
# target : A group of people in purple shirts and tan pants all walking in the same direction .
# predicted : A group of people in white and and tan t walking walking together a city time .
# source : Ein Mann in einem bunten Hemd spielt auf einer Trompete .
# target : A man in a bright shirt is playing trumpet .
# predicted : A man in a colorful green is playing a .
# source : Der Typ mit den Jeansshorts macht im Skatepark ein paar Kunststücke auf seinem Fahrrad .
# target : The guy with the jean shorts is at the skate park doing tricks on his bike .
# predicted : The guy in the denim shorts is on a top park with a on his skateboard .
# source : Mutter und Tochter in Alice-im-Wunderland-Kostümen posieren für ein Foto .
# target : Mother and daughter wearing Alice in wonderland customs are posing for a picture .
# predicted : A and daughter in matching suits a are are posing for a picture .
# source : Ein kleiner Junge verwendet einen Bohrer , um ein Loch in ein Holzstück zu machen .
# target : A little boy using a drill to make a hole in a piece of wood .
# predicted : A little boy is a toy wearing catch a toy in a playground of water .
# source : Zwei Fahrradfahrer fahren auf einer unbefestigten Straße um die Wette .
# target : Two bicyclists are racing each other on a dirt track .
# predicted : Two men are riding on other on a city road .
# source : Dem Mädchen wird eine Frisbeescheibe zugeworfen , während das andere Mädchen darum zu bitten scheint .
# target : A frisbee is being thrown to the girl while the other girl appears to be asking for it .
# predicted : A girl band being arts on catch ball while the other team is to be listening for something .
# source : Ein Kieferorthopäde arbeitet an einem Patienten , während ein Mann die Lampe hält .
# target : An orthodontist working on a patient , while a man holds the light .
# predicted : A old man on a project in while a man is a straw .
# source : Zwei Menschen essen Hamburger auf Gartenstühlen , während ein dritter eine Dose Limonade trinkt .
# target : Two people eat hamburgers on lawn chairs while a third drinks a can of soda .
# predicted : Two people are a on a chairs while a man is is fishing the water .
# source : Zwei Fahrradfahrer fahren an Menschen vorbei die Straße entlang und unterhalten sich dabei .
# target : Two bicyclists ride down the street past people while talking .
# predicted : Two men are past a street on a on walking .
# source : Auf einer Bowlingbahn hält ein Mann in einem schwarzen T-Shirt eine Bowlingkugel und blickt die Bahn hinunter .
# target : At a bowling alley , a man in a black shirt is holding a bowling ball and looking down the lane .
# predicted : A a street game , one man in a black shirt is jumping a bowling ball down down at at ground .
# source : Zwei schwarz gekleidete Männer mit einer grünen und einer roten Fliege treten vor einer Menschenmenge auf .
# target : Two men in black clothes with blue and red bowties are performing in front of a crowd .
# predicted : Two black , black with with a and a jacket are performing a front of a crowd .
# source : Zwei Männer , von denen der eine schwarz und der andere weiß ist , stehen im Freien , spielen Gitarre und singen in ein Mikrofon .
# target : Two men , one black and one white , play their guitars and sing into microphones as they stand outdoors .
# predicted : Two men , one wearing and one in , one the instruments , one , the , a are outside .
# source : Ein Kickboxer landet einen Knietreffer im Gesicht seines Gegners .
# target : A kickboxer lands a flying knee into the face of his opponent .
# predicted : A man is a four board - a mirror of a face .
# source : Drei Menschen laufen auf einer roten Bahn um die Wette .
# target : Three people are running a race around a red track .
# predicted : Three men are walking on street on a dirt track .
# source : Footballspieler haben Schwierigkeiten , bei ihren Spielzügen durch die stabile Linie zu dringen .
# target : Football players struggle to get plays through a tough line .
# predicted : Football players in to catch a a a parking area .
# source : Mehrere Männer beten , während sie am Ende eines Tisches mit Essen stehen .
# target : Several men are praying while standing at the end of a table of food .
# predicted : Several people are picking , a in the end of a table with food .
# source : Zwei indische Kinder in formeller Tracht führen fröhlich einen rituellen Tanz auf .
# target : Two Indian children in formal costume happily performing a ritual dance .
# predicted : Two men women in formal attire are performing a dance dance .
# source : Drei Kinder stehen nahe beieinander an einem hohen blauen Holzpfahl .
# target : Three children standing near each other and next to a tall blue wooden post .
# predicted : Three men are near a other near outside to a large green and building .
# source : Eine Gruppe von Menschen läuft .
# target : A group of people are running .
# predicted : A dog of people are walking in
# source : Zwei Frauen gehen den Strand entlang und tragen dabei Bretter und Flossen .
# target : Two women are walking down the beach carrying boards and flippers .
# predicted : Two men are walking on the beach and a and tools .
# source : Ein Junge sitzt auf einem Felsen und blickt in das Tal unter ihm .
# target : A boy is sitting on a rock , looking at the valley below .
# predicted : A man in sitting on a rock looking looking out a scenery line .
# source : Eine Frau steht auf einem Bein auf einer hohen Klippe und blickt über einen Fluss .
# target : A woman standing on a high cliff on one leg looking over a river .
# predicted : A woman in on a sidewalk lift in a of is out a railing .
# source : Eine brünette Frau steht auf dem Gehweg und blickt die Straße hinunter .
# target : A brunette woman is standing on the sidewalk looking down the road .
# predicted : A woman woman stands standing on a sidewalk looking at the street .
# source : Eine Gruppe von drei Freunden unterhält sich in einem Haus .
# target : A group of three friends are conversing inside of a home .
# predicted : A woman of three friends are standing in a a fountain .
# source : Zwei Chinesen stehen an einer Wandtafel .
# target : Two chinese people are standing by a chalkboard .
# predicted : Two men women are standing on the street .
# source : Eine Person in Bluejeans und rotem Pullover biegt um die Ecke einer Ziegelmauer .
# target : A person wearing blue jeans and a red sweater us turning the corner of a brick wall .
# predicted : A woman in jeans and and a sweater sweater is a on wall of a large building .
# source : Bauern betreiben tagsüber ihre Landwirtschaft .
# target : Farmers are performing their agriculture during the day .
# predicted : A divers playing the routine on the beach .
# source : Bei einer Art Jahrmarkt stellt ein Mann Zuckerwatte her .
# target : At some sort of carnival , a man is making cotton candy .
# predicted : A a kind of construction workers a man having having a candy .
# source : Eine Gruppe von Polizisten steht vor einem Bus .
# target : A bunch of police officers are standing outside a bus .
# predicted : A woman of bicyclists officers stand standing in of bus .
# source : Eine ältere weißhaarige Frau sieht in ihre Kasse und blickt durch ihre Brillengläser hindurch .
# target : A elderly white - haired woman is looking inside her register and looking through her glasses .
# predicted : An older woman woman haired woman looks enjoying at her wares in down at the hands .
# source : Zwei Männer stehen an Telefonzellen im Freien .
# target : Two men are standing at telephone booths outside .
# predicted : Two men are standing on the on outside .
# source : Zwei Frauen in Rot und ein Mann , der aus einer transportablen Toilette kommt .
# target : Two women wearing red and a man coming out of a port - a - potty .
# predicted : Two women are red and red man are out of a wooden - like concrete screen .
# source :
# target :
# predicted : A
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\Advance DL\Transformer\main.ipynb Cell 15' in <cell line: 2>()
#      <a href='vscode-notebook-cell:/d%3A/Advance%20DL/Transformer/main.ipynb#ch0000020?line=9'>10</a> logits = model(src, trg_input)
#      <a href='vscode-notebook-cell:/d%3A/Advance%20DL/Transformer/main.ipynb#ch0000020?line=10'>11</a> for j in range(64):
# ---> <a href='vscode-notebook-cell:/d%3A/Advance%20DL/Transformer/main.ipynb#ch0000020?line=11'>12</a>         src_words = idx_to_word(src[j], src_vocab)
#      <a href='vscode-notebook-cell:/d%3A/Advance%20DL/Transformer/main.ipynb#ch0000020?line=12'>13</a>         trg_words = idx_to_word(trg[j], trg_vocab)
#      <a href='vscode-notebook-cell:/d%3A/Advance%20DL/Transformer/main.ipynb#ch0000020?line=13'>14</a>         output_words = logits[j].max(dim=1)[1]
#
# IndexError: index 55 is out of bounds for dimension 0 with size 55
